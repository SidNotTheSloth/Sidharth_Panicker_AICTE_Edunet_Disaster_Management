# %% [markdown]
# Project Title
#
# Wildfire Risk Prediction using Climate & Vegetation Drivers

# %% [markdown]
# Problem Statement
#
# Wildfires are becoming more frequent and severe due to climate change, prolonged droughts, and increased vegetation flammability. Predicting whether a wildfire will ignite (Yes/No) based on factors like temperature, precipitation, wind speed, vegetation, and historical trends can enhance early warning systems and improve wildfire management strategies.

# %% [markdown]
# Dataset
#
# California Weather and Fire Prediction Dataset (1984–2025) with Engineered Features (Zenodo)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('/content/CA_Weather_Fire_Dataset_1984-2025.csv')

print(df.head(), "\n")

print(df.info(), "\n")

print(df.describe(), "\n")

print(df.isnull().sum(), "\n")

#Visualization
if 'FIRE_START_DAY' in df.columns:
    plt.figure(figsize=(6,4))
    sns.countplot(x='FIRE_START_DAY', data=df, palette='Set2')
    plt.title("Wildfire Ignition Distribution (Target Variable)")
    plt.show()

# Correlation heatmap of numerical features
plt.figure(figsize=(12,6))
sns.heatmap(df.corr(numeric_only=True), annot=False, cmap='coolwarm')
plt.title("Correlation Heatmap of Climate Features")
plt.show()
# Out:
#          DATE  PRECIPITATION  MAX_TEMP  MIN_TEMP  AVG_WIND_SPEED  \
# 0  1984-01-01            0.0      79.0      51.0            4.70
# 1  1984-01-02            0.0      71.0      46.0            5.59
# 2  1984-01-03            0.0      70.0      47.0            5.37
# 3  1984-01-04            0.0      76.0      45.0            4.70
# 4  1984-01-05            0.0      74.0      49.0            5.14
#
#    FIRE_START_DAY  YEAR  TEMP_RANGE  WIND_TEMP_RATIO  MONTH  SEASON  \
# 0           False  1984        28.0         0.059494      1  Winter
# 1           False  1984        25.0         0.078732      1  Winter
# 2           False  1984        23.0         0.076714      1  Winter
# 3           False  1984        31.0         0.061842      1  Winter
# 4           False  1984        25.0         0.069459      1  Winter
#
#    LAGGED_PRECIPITATION  LAGGED_AVG_WIND_SPEED  DAY_OF_YEAR
# 0                   0.0                  4.700            1
# ...
